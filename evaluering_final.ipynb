# %% [markdown]
# ## Första resultatet (ingen analys utan bara resultat).
#
# ================================================================================
# FRÅGA: Vad är ett skot?
#
# BOTSVAR:
# Här kommer information om vad ett skot är baserat på kursmaterialet:
#
# **1. Kort svar**
# Ett skot är en tamp (lina) som används för att reglera seglets riktning i förhållande till vinden och för att justera seglets form.
#
# **2. Förklaring**
# Skotet används aktivt när man seglar för att kontrollera seglets position. Genom att "skota hem" drar du in skotet så att seglet kommer närmare båtens centrumlinje. Om du istället vill släppa ut på seglet använder du termen "slacka". För att hantera skotet och underlätta arbetet när det är tungt används en vinsch, och för att låsa fast skotet i ett visst läge används en avlastare.
#
# **3. Viktiga detaljer**
# *   **Säkerhet vid avlastare:** Det är mycket viktigt att aldrig släppa en avlastare om inte skotet är säkert surrat runt vinschen.
# *   **Skillnad mot fall:** Medan skotet reglerar seglets riktning och form, används ett fall för att hissa eller sänka ett segel.
#
# EVALUERING:
# Poäng: 1
#
# Motivering: AI-assistentens svar är korrekt, tydligt och innehåller den kärninformation som efterfrågades i det önskade svaret. Att assistenten dessutom ger en fördjupad kontext gör svaret mycket bra och hjälpsamt.
# ================================================================================
# FRÅGA: Vad betyder babord?
#
# BOTSVAR:
# 1. Kort svar
# Babord är den vänstra sidan av båten när du är vänd mot fören.
#
# 2. Förklaring
# Inom segling använder vi specifika termer för båtens sidor för att kunna kommunicera tydligt och undvika missförstånd. Babord är den nautiska termen för vänster sida. För att veta vilken sida som är babord ska du alltid utgå från att du står i båten och tittar framåt mot fören (den främre delen av båten).
#
# 3. Viktiga detaljer
# Det är viktigt att skilja på babord och styrbord (som är båtens högra sida) för att navigering och manövrering ska ske säkert och enhetligt ombord.
#
# EVALUERING:
# Poäng: 1
#
# Motivering: Svaret innehåller den korrekta definitionen som efterfrågades och förklarar begreppet på ett tydligt och korrekt sätt. Den extra kontexten är korrekt och bidrar till förståelsen utan att avvika från kärnan i frågan.
# ================================================================================
# FRÅGA: Vad är viktigt att tänka på vid tilläggning i hård vind?
#
# BOTSVAR:
# Vid tilläggning i hård vind, eller vid risk för starka vindar under natten, är det viktigt att vidta omfattande säkerhetsåtgärder för att skydda både båt och besättning.
#
# ### 1. Kort svar
# Vid tilläggning i stark vind bör du prioritera en säker hamnplats, noggrann förberedelse av båten (fendring och säkring av utrustning) samt vara beredd att använda extra förtöjningslinor för att stabilisera båten.
#
# ### 2. Förklaring
# Baserat på kursmaterialet innebär förberedelser inför starka vindar följande steg:
# *   **Välj rätt plats:** Se till att förtöja i en skyddad hamn.
# *   **Säkra båtens utrustning:**
#     *   Fendra ordentligt.
#     *   Säkra eller plocka in lösa dynor.
#     *   Fäll ihop biminin.
#     *   Rulla in förseglet ordentligt och se till att några varv av skotet är upprullat.
#     *   Se till att segelsäcken är ordentligt stängd.
#     *   Placera landgången så att den inte riskerar att hamna i kläm mellan båt och kaj om båten rör sig.
# *   **Förtöjning:** Använd extra linor eller extra spring för att säkra upp båten ordentligt.
# *   **Planering och kommunikation:** Eftersom tilläggning är en svår manöver ska du alltid prata igenom planen med din besättningskamrat. Informera även gästerna tydligt om säkerhet, särskilt att de aldrig får sätta händer eller fötter mellan båten och bryggan.
#
# ### 3. Viktiga detaljer
# *   **Ankring:** Om du ankrar upp mot kaj, kom ihåg att göra en noggrann bedömning av vindriktning och vindstyrka innan du påbörjar manövern. Titta på hur andra båtar ligger för att förstå hur du bör lägga dig.
# *   **Ankarspelet:** Tänk på att inte spänna upp ankaret för mycket med ankarspelet då detta kan överbelasta och skada spelet. Om du behöver spänna upp mer, släpp hellre ut på aktertamparna och backa för att spänna upp kättingen.
# *   **Kontroll:** Innan tilläggningen anses klar, backa på ankaret och höj varvtalet för att säkerställa att det sitter ordentligt (att det inte "draggar", det vill säga släpar över botten).
# *   **Avlastning:** Efter tilläggningen ska en avlastningstamp (avlastare) sättas i kättingen och fästas i knaparna så att tyngden hamnar på tampen istället för på ankarspelet.
#
# EVALUERING:
# **Poäng: 0.5**
#
# **Motivering:** AI-assistentens svar är faktamässigt korrekt och innehåller en mycket god och uttömmande teknisk genomgång av säkerhetsrutiner vid tilläggning. Svaret missar dock att fånga den pedagogiska kärnan i det önskade svaret, som betonar det mänskliga perspektivet (kommunikation med besättning/gäster och att "ta det lugnt"). AI:n fokuserar nästan uteslutande på tekniska moment snarare än den trygghetsskapande planering som efterfrågas i det önskade svaret.
# ================================================================================
# FRÅGA: När ska flytväst användas?
#
# BOTSVAR:
# Här är information gällande när flytväst ska användas ombord:
#
# **1. Kort svar**
# Flytväst ska bäras av alla icke simkunniga ombord. För övriga personer beslutas användningen av skepparen eller personalen utifrån situationen.
#
# **2. Förklaring**
# Skepparen och värdarna har ansvaret att bedöma när säkerhetsläget kräver flytväst. Vid lugnt väder är det frivilligt för simkunniga att bära flytväst, men personalen har alltid rätt att kräva att de tas på om situationen så kräver. Det kan till exempel handla om att vädret blir sämre, om en gäst uppträder berusat, eller om det finns barn ombord som rör sig mycket på båten. Som personal har ni veto – om ni anser att någon bör bära flytväst ska den sättas på.
#
# **3. Viktiga detaljer**
# *   **Barn:** Barn som inte är simkunniga ska alltid bära flytväst. För äldre barn och ungdomar under 18 år ligger ansvaret i första hand hos föräldrarna, men personalen har alltid veto och kan kräva att flytväst används om ni bedömer att det behövs för säkerheten.
# *   **Individuella beslut:** Det är inte ett krav att utlysa påbud om flytväst för alla ombord samtidigt; ni kan fatta beslut om att en enskild person, till exempel en berusad gäst, ska bära flytväst.
# *   **Säkerhetsgenomgång:** När ni kommer ombord på en ny båt ska ni alltid lokalisera och räkna flytvästarna, samt informera gästerna om var de finns under säkerhetsgenomgången. Kom ihåg att hämta mindre västar om ni har barn ombord.
#
# EVALUERING:
# Poäng: 1
#
# Motivering: AI-assistenten täcker in alla väsentliga delar av det önskade svaret, inklusive ansvarsfördelningen mellan personal och föräldrar samt riktlinjer för barn och simkunniga. Svaret är tydligt, professionellt strukturerat och stämmer väl överens med instruktionerna.
# ================================================================================
# FRÅGA: En gäst är uppenbart missnöjd vad ska jag göra?
#
# BOTSVAR:
# 1. **Kort svar**
# Om en gäst är missnöjd ska du uppmärksamma dem, prata med dem avskilt från övriga gäster, lyssna på deras upplevelse och fråga vad ni kan göra för att förbättra situationen.
#
# 2. **Förklaring**
# Det är avgörande att alla gäster känner sig sedda, även de som är mindre positiva eller uttrycker missnöje. När någon klagar finns en risk för en negativ spiral där fler gäster dras med och stämningen ombord trissas upp. Genom att ta ett enskilt samtal med den missnöjda gästen visar du att du tar deras upplevelse på allvar och arbetar aktivt för att förhindra att den negativa stämningen sprider sig till resten av gruppen. Målet är att förstå vad som ligger bakom missnöjet och se om det finns konkreta åtgärder som kan göra vistelsen bättre för dem.
#
# 3. **Viktiga detaljer**
# * **Var proaktiv:** Om missnöjet beror på brister i båtens underhåll eller renhållning (vilket är ett vanligt klagomål), är det viktigt att du som skeppare ser till att dina uppgifter utförs korrekt, exempelvis genom en noggrann incheckning för att upptäcka och åtgärda fel i tid.
# * **Bemötande:** Som skeppare och värd är det ditt ansvar att leverera en trevlig semester. Även om du är trött mot slutet av din jobbperiod får detta aldrig gå ut över gästerna.
# * **Sök avlastning:** Om du känner att du inte orkar prestera på den nivå som krävs, kontakta närmaste ansvarig för att få hjälp med avlastning istället för att låta det påverka gästernas upplevelse negativt.
#
# EVALUERING:
# Poäng: 0.5
#
# Motivering: AI-assistenten ger en bra och professionell guide för hur man bemöter en missnöjd gäst i stunden, men den missar den kritiska instruktionen i det önskade svaret: att alltid informera platsansvarig eller kontoret. Det är en väsentlig del av rutinen som saknas i assistentens svar.
# ================================================================================
# FRÅGA: En gäst missköter sig och beter sig otrevligt, Vad ska jag göra?
#
# BOTSVAR:
# Här är instruktionerna för hur du ska hantera en gäst som missköter sig eller uppträder otrevligt ombord:
#
# ### 1. Kort svar
# Du ska agera genom att inleda en dialog, markera gränser och vid behov involvera ansvariga. Om gästens beteende är allvarligt eller inte upphör, har du rätt att avlägsna gästen från båten (avmönstring).
#
# ### 2. Förklaring
# *   **Dialog och varning:** Vid otrevligt beteende eller negativ inverkan på stämningen ombord ska du alltid börja med att prata med gästen. Försök ta samtalet avskilt från övriga gäster. Fråga hur de har det och om det är något du kan göra för att situationen ska bli bättre. Om beteendet innebär att gästen äventyrar säkerheten eller stör andra, ska du ge en tydlig varning.
# *   **Involvera ansvariga:** Om situationen inte förbättras efter dialog/varning, eller om gästen trakasserar personalen, ska du involvera platsansvarig och produktionsansvarig tidigt i processen för att få stöd och korrekt bedömning.
# *   **Avmönstring:** Om gästen trots varning fortsätter att missköta sig på ett sätt som väsentligt bryter mot ordningsreglerna, har du rätt att låta gästen mönstra av vid närmaste hamn.
#
# ### 3. Viktiga detaljer
# *   **Den utsattas upplevelse:** Det är alltid den utsattas upplevelse som avgör om en situation ska rapporteras och följas upp. Om du känner dig behandlad på ett oacceptabelt sätt ska du alltid meddela detta omedelbart.
# *   **Resevillkoren:** Enligt våra resevillkor är gästen skyldig att följa anvisningar och ordningsregler. Om en gäst bryter mot detta på ett väsentligt sätt kan avtalet hävas utan rätt till ersättning eller återbetalning för gästen.
# *   **Negativa spiraler:** Var uppmärksam på att negativa gäster kan dra med sig andra. Det är ditt ansvar som skeppare/värd att bryta denna spiral tidigt genom den enskilda dialogen, så att stämningen ombord förblir god och respektfull för alla gäster.
#
# EVALUERING:
# Poäng: 1
#
# Motivering: AI-assistenten täcker in alla väsentliga delar av det önskade svaret (dialog, inkoppling av ansvarig och rätten till avlägsnande). Svaret är dessutom välstrukturerat och ger ett professionellt och tydligt råd för hur situationen ska hanteras i praktiken.
# ================================================================================
# FRÅGA: Vad är Zlatan otok för ställe?
#
# BOTSVAR:
# Jag vet inte baserat på kursmaterialet.
#
# Det finns ingen information i materialet om en plats med namnet "Zlatan otok". Däremot beskrivs ön **Zlarin**, som bland annat är känd för sin koralltillverkning och sina gemytliga restauranger.
#
# EVALUERING:
# Poäng: 0
#
# Motivering: AI-assistenten misslyckas helt med att besvara frågan och försöker istället gissa på en annan ö (Zlarin). Eftersom det önskade svaret innehåller specifik information om Zlatan Otok som AI:n borde ha levererat, är svaret inte godkänt.
# ================================================================================
# FRÅGA: Vem är Malin?
#
# BOTSVAR:
# 1. Kort svar
# Malin Stom är en av grundarna till More Sailing.
#
# 2. Förklaring
# Malin Stom startade företaget tillsammans med Einar Halldin år 2009. Deras ursprungliga upplägg var att de själva hyrde en segelbåt och arbetade ombord som skeppare och värd, samtidigt som de sålde resorna via en hemsida de byggt och designat på egen hand.
#
# 3. Viktiga detaljer
# Det var genom detta initiativ som seglingsresor introducerades som koncept på resemarknaden sommaren 2009, med målet att erbjuda segling för alla oavsett tidigare erfarenhet.
#
# EVALUERING:
# Poäng: 1
#
# Motivering: Svaret innehåller den efterfrågade informationen (att hon är en av grundarna till More Sailing) och ger dessutom korrekt kontextuell information som bekräftar att assistenten identifierat rätt person. Svaret uppfyller kriterierna för det önskade svaret med råge.
# ================================================================================
# FRÅGA: Vem är Gustav?
#
# BOTSVAR:
# Jag vet inte baserat på kursmaterialet.
#
# EVALUERING:
# Poäng: 1
#
# Motivering: AI-assistentens svar är i princip identiskt med det önskade svaret, då båda uttrycker samma sak och det önskade svaret innehåller exakt samma information.
# ================================================================================
# FRÅGA: Hur skapar man en RAG-chattbot?
#
# BOTSVAR:
# Jag vet inte baserat på kursmaterialet.
#
# EVALUERING:
# Poäng: 1
#
# Motivering: AI-assistentens svar är ordagrant detsamma som det önskade svaret, vilket innebär att det uppfyller kriteriet för att vara "väldigt nära" (i det här fallet identiskt) det önskade svaret.
# ================================================================================
# FRÅGA: Vad betyder styrbord?
#
# BOTSVAR:
# 1. **Kort svar**
# Styrbord är båtens högra sida när du är vänd mot fören.
#
# 2. **Förklaring**
# Inom segling använder vi specifika termer för att beskriva båtens sidor för att säkerställa tydlig och effektiv kommunikation. När du står ombord på båten och tittar framåt (mot fören), är styrbord alltid den sida som befinner sig till höger. Motsatsen till styrbord är babord, vilket är den vänstra sidan.
#
# 3. **Viktiga detaljer**
# Det är viktigt att komma ihåg att dessa definitioner är kopplade till båtens riktning (framåt/fogen) snarare än var du som person befinner dig eller åt vilket håll du tittar. Genom att använda dessa fasta termer undviker man missförstånd vid navigering och manövrering.
#
# EVALUERING:
# Poäng: 1
#
# Motivering: AI-assistentens svar är korrekt, tydligt och innehåller all nödvändig information. Det matchar det önskade svaret väl och ger dessutom en pedagogisk kontext som hjälper användaren att förstå begreppet ännu bättre.

# %% [markdown]
# # Evaluering

# %%
import os
from google import genai
from dotenv import load_dotenv
from google.genai import types
from embedding_service import EmbeddingService
from vector_store import VectorStore
store = VectorStore("embeddings_v2.parquet")
load_dotenv()
client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
service = EmbeddingService(client, types)

# %%
def build_prompt(query, results):
    context = "\n\n".join(
        [r["text"] for r in results]
    )

    prompt = f"""
Du är en AI-assistent som hjälper skeppare och värdar på More Sailing att förstå kursmaterialet på ett korrekt och professionellt sätt.

Ditt mål är att:
- Ge korrekta och fullständiga svar baserade på kursmaterialet
- Hjälpa användaren att förstå detaljer och sammanhang
- Fungera som en pålitlig kunskapskälla

Dina svar ska:
- Vara tydliga och välstrukturerade
- Innehålla tillräckligt med detaljer för att ge en korrekt förståelse
- Använda korrekt terminologi från kursmaterialet

Regler:
- Använd ENDAST informationen i kontexten nedan
- Hitta inte på information
- Om svaret inte finns i kontexten: säg "Jag vet inte baserat på kursmaterialet"

Om möjligt:
- Förklara begrepp tydligt
- Ge sammanhang så att användaren förstår varför något görs
- Knyt till praktiska situationer om det framgår i materialet

När du svarar:
- Prioritera konkreta instruktioner och regler från kursmaterialet
- Ta med viktiga åtgärder (t.ex. att informera ansvarig)
- Fokusera inte enbart på tekniska detaljer utan även beteende och ansvar

Svara i följande struktur:
1. Kort svar
2. Förklaring
3. Eventuella viktiga detaljer eller undantag

KONTEXT:
{context}

FRÅGA:
{query}
"""
    return prompt

# %%
def ask(query, store, service, client, k=3):
    """
    Enkel RAG-funktion:
    - tar en fråga (query)
    - hämtar relevanta chunks
    - bygger prompt
    - skickar till LLM
    """

    # 1. Embedda fråga
    query_embedding = service.embed(query)

    # 2. Sök i VectorStore
    results = store.search(query_embedding, k=k)

    # 3. Bygg prompt
    prompt = build_prompt(query, results)

    # 4. Skicka till modell (med enkel retry)
    import time

    for attempt in range(3):
        try:
            response = client.models.generate_content(
                model="gemini-3.1-flash-lite-preview",
                contents=prompt
            )
            return response.text
        except Exception as e:
            print(f"Försök {attempt+1} misslyckades: {e}")
            time.sleep(5)

    return "Kunde inte få svar från modellen just nu."

# %%
validation_data = [
    {
        "question": "Vad är ett skot?",
        "ideal_answer": "Ett skot är ett rep/tamp på en segelbåt som används för att justera seglets vinkel mot vinden."
    },
    {
        "question": "Vad betyder babord?",
        "ideal_answer": "Babord är vänster sida av båten när man tittar framåt mot fören."
    },
    {
        "question": "Vad är viktigt att tänka på vid tilläggning i hård vind?",
        "ideal_answer": "Det är viktigt att tänka på säkerheten så att ingen skadar sig, Planera i förtid och kommunicera med din värd och förklara vad och hur ni ska göra, förbered båten med tampar och fendrar och ta det lungt."
    },
    {
        "question": "När ska flytväst användas?",
        "ideal_answer": " Det är vanligtvist frivilligt att använda flytväst när vädret är lungt, men om ni i personalen tycker att situationen kräver att flytväst ska bäras så är det det som gäller. När det gälller barn så ska de alltid bära flytväst om de inte är simkunniga. För äldre barn under 18 så är det föräldrarna som bestämmer om inte ni bestämt att de ska ha flytväst. Flytväst ska alltid bäras på däck av små barn"
    },
    {
        "question": "En gäst är uppenbart missnöjd vad ska jag göra?",
        "ideal_answer": "Prata med gästen och försök lös problemet och informera alltid platsansvarig eller kontoret, detta är väldigt viktigt!"
    },
    {
        "question": "En gäst missköter sig och beter sig otrevligt, Vad ska jag göra?",
        "ideal_answer": "Om en gäst missköter sig så har ni rätt att avlägsna gästen från resan. Innan detta sker så är det viktigt att ni haft en dialog med gästen och kopplat in platsansvarig för bedömmning, hjälp och stöd."
    },
    {
        "question": "Vad är Zlatan otok för ställe?",
        "ideal_answer": "Zlatan Otok är en av Kroatiens bästa vingårdar. Vi förtöjer i dras hamn där de erbjuder middag och vinprovning, man får inte besöka själva vingården. För den som är intresserad så finns en stor grotta ca 3 km upp för ett berg med en fantastisk utsikt. Viktigt att tänka på är att hamnen är väldigt utsatt för vind och inte att föredra när det blåser mycket."
    },
    {
        "question": "Vem är Malin?",
        "ideal_answer": "Malin är en utav grundarna av More Sailing"
    },
    {
        "question": "Vem är Gustav?",
        "ideal_answer": "Jag vet inte baserat på kursmaterialet"
    },
    {
        "question": "Hur skapar man en RAG-chattbot?",
        "ideal_answer": "Jag vet inte baserat på kursmaterialet"
    },
    {
        "question": "Vad betyder styrbord?",
        "ideal_answer": "Styrbord är höger sida av båten när man tittar framåt mot fören."
    }
]

# %%
for item in validation_data:
    query = item["question"]
    ideal_answer = item["ideal_answer"]

    bot_answer = ask(query, store, service, client)

    evaluation_prompt = f"""
Du är ett intelligent utvärderingssystem vars uppgift är att utvärdera en AI-assistents svar.
Om svaret är väldigt nära det önskade svaret, sätt poängen 1.
Om svaret är felaktigt eller inte bra nog, sätt poängen 0.
Om svaret är delvis i linje med det önskade svaret, sätt poängen 0.5.
Motivera kort varför du sätter den poäng du gör.

Fråga: {query}
AI-assistentens svar: {bot_answer}
Önskat svar: {ideal_answer}
"""

    evaluation_response = client.models.generate_content(
        model="gemini-3.1-flash-lite-preview",
        contents=evaluation_prompt
    )

    print("=" * 80)
    print("FRÅGA:", query)
    print("\nBOTSVAR:")
    print(bot_answer)
    print("\nEVALUERING:")
    print(evaluation_response.text)
# Out:
# ...
# FRÅGA: Vad är ett skot?
#
# BOTSVAR:
# 1. Kort svar
# Ett skot är den tamp (lina) som används för att reglera ett segels riktning i förhållande till vinden och därmed även seglets form.
#
# 2. Förklaring
# Skotet är en central del av båtens rigg och hantering. Genom att "skota hem" (dra in skotet) flyttar du seglet närmare båtens centerlinje, vilket ändrar seglets form och vinkel mot vinden. När du vill minska spänningen eller låta seglet gå ut mer, "slackar" du på skotet.
#
# Eftersom skotet ofta används under belastning används vinchar för att underlätta arbetet med att ta hem skotet, samt avlastare för att låsa fast det i ett visst läge.
#
# 3. Viktiga detaljer
# Det är mycket viktigt att aldrig släppa på en avlastare om inte skotet är ordentligt surrat (taget om) runt en vinsch. Om du släpper avlastaren utan att ha kontroll över tampen på vinschen kan seglet plötsligt löpa ut okontrollerat, vilket kan orsaka skador på utrustning eller personer ombord.
#
# EVALUERING:
# Poäng: 1
# ...

# %% [markdown]
# # Vidare analys

# %% [markdown]
# ## Ändring av prompt för att lösa dessa.
#
# Kommunikation är något av det viktigaste som finns på havet och något som trycks väldigt mycket på i kursmaterialet. Jag la därför till detta i prompten för styra modellen till att spegla detta bättre. Detta gav minimalt bättre resultat. Problemet ligger förmodligen i att texten innehåller så otroligt mycket teknisk eller generell information vilket leder till att dessa korta instruktioner inte är lika framträdande.
#
# När du svarar:
# - Prioritera konkreta instruktioner och regler från kursmaterialet
# - Ta med viktiga åtgärder (t.ex. att informera ansvarig)
# - Fokusera inte enbart på tekniska detaljer utan även beteende och ansvar
#
# ### Resultaten med 0,5
#
# ================================================================================
# FRÅGA: Vad är viktigt att tänka på vid tilläggning i hård vind?
#
# BOTSVAR:
# Vid tilläggning i hård vind, eller vid risk för starka vindar under natten, är det viktigt att vidta omfattande säkerhetsåtgärder för att skydda både båt och besättning.
#
# ### 1. Kort svar
# Vid tilläggning i stark vind bör du prioritera en säker hamnplats, noggrann förberedelse av båten (fendring och säkring av utrustning) samt vara beredd att använda extra förtöjningslinor för att stabilisera båten.
#
# ### 2. Förklaring
# Baserat på kursmaterialet innebär förberedelser inför starka vindar följande steg:
# *   **Välj rätt plats:** Se till att förtöja i en skyddad hamn.
# *   **Säkra båtens utrustning:**
#     *   Fendra ordentligt.
#     *   Säkra eller plocka in lösa dynor.
#     *   Fäll ihop biminin.
#     *   Rulla in förseglet ordentligt och se till att några varv av skotet är upprullat.
#     *   Se till att segelsäcken är ordentligt stängd.
#     *   Placera landgången så att den inte riskerar att hamna i kläm mellan båt och kaj om båten rör sig.
# *   **Förtöjning:** Använd extra linor eller extra spring för att säkra upp båten ordentligt.
# *   **Planering och kommunikation:** Eftersom tilläggning är en svår manöver ska du alltid prata igenom planen med din besättningskamrat. Informera även gästerna tydligt om säkerhet, särskilt att de aldrig får sätta händer eller fötter mellan båten och bryggan.
#
# ### 3. Viktiga detaljer
# *   **Ankring:** Om du ankrar upp mot kaj, kom ihåg att göra en noggrann bedömning av vindriktning och vindstyrka innan du påbörjar manövern. Titta på hur andra båtar ligger för att förstå hur du bör lägga dig.
# *   **Ankarspelet:** Tänk på att inte spänna upp ankaret för mycket med ankarspelet då detta kan överbelasta och skada spelet. Om du behöver spänna upp mer, släpp hellre ut på aktertamparna och backa för att spänna upp kättingen.
# *   **Kontroll:** Innan tilläggningen anses klar, backa på ankaret och höj varvtalet för att säkerställa att det sitter ordentligt (att det inte "draggar", det vill säga släpar över botten).
# *   **Avlastning:** Efter tilläggningen ska en avlastningstamp (avlastare) sättas i kättingen och fästas i knaparna så att tyngden hamnar på tampen istället för på ankarspelet.
#
# EVALUERING:
# **Poäng: 0.5**
#
# **Motivering:** AI-assistentens svar är faktamässigt korrekt och innehåller en mycket god och uttömmande teknisk genomgång av säkerhetsrutiner vid tilläggning. Svaret missar dock att fånga den pedagogiska kärnan i det önskade svaret, som betonar det mänskliga perspektivet (kommunikation med besättning/gäster och att "ta det lugnt"). AI:n fokuserar nästan uteslutande på tekniska moment snarare än den trygghetsskapande planering som efterfrågas i det önskade svaret.
#
# ================================================================================
#
# FRÅGA: En gäst är uppenbart missnöjd vad ska jag göra?
#
# BOTSVAR:
# 1. **Kort svar**
# Om en gäst är missnöjd ska du uppmärksamma dem, prata med dem avskilt från övriga gäster, lyssna på deras upplevelse och fråga vad ni kan göra för att förbättra situationen.
#
# 2. **Förklaring**
# Det är avgörande att alla gäster känner sig sedda, även de som är mindre positiva eller uttrycker missnöje. När någon klagar finns en risk för en negativ spiral där fler gäster dras med och stämningen ombord trissas upp. Genom att ta ett enskilt samtal med den missnöjda gästen visar du att du tar deras upplevelse på allvar och arbetar aktivt för att förhindra att den negativa stämningen sprider sig till resten av gruppen. Målet är att förstå vad som ligger bakom missnöjet och se om det finns konkreta åtgärder som kan göra vistelsen bättre för dem.
#
# 3. **Viktiga detaljer**
# * **Var proaktiv:** Om missnöjet beror på brister i båtens underhåll eller renhållning (vilket är ett vanligt klagomål), är det viktigt att du som skeppare ser till att dina uppgifter utförs korrekt, exempelvis genom en noggrann incheckning för att upptäcka och åtgärda fel i tid.
# * **Bemötande:** Som skeppare och värd är det ditt ansvar att leverera en trevlig semester. Även om du är trött mot slutet av din jobbperiod får detta aldrig gå ut över gästerna.
# * **Sök avlastning:** Om du känner att du inte orkar prestera på den nivå som krävs, kontakta närmaste ansvarig för att få hjälp med avlastning istället för att låta det påverka gästernas upplevelse negativt.
#
# EVALUERING:
# Poäng: 0.5
#
# Motivering: AI-assistenten ger en bra och professionell guide för hur man bemöter en missnöjd gäst i stunden, men den missar den kritiska instruktionen i det önskade svaret: att alltid informera platsansvarig eller kontoret. Det är en väsentlig del av rutinen som saknas i assistentens svar.

# %% [markdown]
# ## Analys av misslyckande av Zlatan otok fråga
#
# Frågan om Zlatan Otok misslyckades trots att relevant information fanns i de hämtade chunkarna (vilket jag undersökt). Problemet ligger inte i retrievalen, utan i hur informationen är chunkad. Informationen om Zlatan Otok är inbäddad i större textstycken tillsammans med mycket annan information, vilket skapar brus och gör det svårt för modellen att identifiera vad som är relevant för frågan.
#
# En annan utmaning är att många destinationer i materialet är semantiskt lika. Det är många Öar och destinationer i Dalmatiska skärgården som beskrivs med resturanger, vingårdar och sevärdigheter, vilket även det skapar brus och försvårar prioriteringen av rätt information.
#
# RAG-modellen är också väldigt bred och generell. Detta försvårar både retrieval och promptdesign. Prompten jag kom fram till efter mycket exprimenterande fungerar
# bra för exempelvis frågor om gästhantering, säkerhet eller segling men dess instruktioner passar inte för destinationer.
#
# För att lösa dessa problem skulle vi kunna göra en helt egen RAG bara för destinationer. Då hade man lättare kunnat arbeta med chunksen men också en bra prompt för dessa frågor. Det är dock utanför denna uppgiftens scope. Hade vi ändå velat fortsätta med en komplett modell, så hade vi definitivt behövt arbeta mer med chunksen och datarensning men det finns de inte mer tid till i denna uppgiften.
#
#
# Fråga och förväntat svar:
# "question": "Vad är Zlatan otok för ställe?",
#
#  "ideal_answer": "Zlatan Otok är en av Kroatiens bästa vingårdar. Vi förtöjer i dras hamn där de erbjuder middag och vinprovning, man får inte besöka själva vingården. För den som är intresserad så finns en stor grotta ca 3 km upp för ett berg med en fantastisk utsikt. Viktigt att tänka på är att hamnen är väldigt utsatt för vind och inte att föredra när det blåser mycket."
#
#  Evalueringen:
#  FRÅGA: Vad är Zlatan otok för ställe?
#
# BOTSVAR:
# Jag vet inte baserat på kursmaterialet.
#
# Det finns ingen information i materialet om en plats med namnet "Zlatan otok". Däremot beskrivs ön **Zlarin**, som bland annat är känd för sin koralltillverkning och sina gemytliga restauranger.
#
# EVALUERING:
# Poäng: 0
#
# Motivering: AI-assistenten misslyckas helt med att besvara frågan och försöker istället gissa på en annan ö (Zlarin). Eftersom det önskade svaret innehåller specifik information om Zlatan Otok som AI:n borde ha levererat, är svaret inte godkänt.

# %% [markdown]
# Undersöker chunksen för Zlatan otok med olika nyckelord.
#
# Vid en närmre titt så visar det sig att informationen fasktiskt finnns med i de hämtade chunksen men att eftersom att chunksen är så stora så verkar informationen här drunkna i annan information vilket skapar brus. Detta gör det svårare för modellen att lyfta rätt detaljer
#
# En annan utmaning verkar vara att många platser i materialet är semantiskt lika varandra. Flera öar och hamnar i den Dalmatiska skärgården beskrivs på liknande sätt med vingårdar, resturanger och sevärdigheter. Det ökar risken för hallucinationer.
#
# En förbättring man hade kunnat göra är att dels arbeta mer med chunking och datarensning men också ge användaren möjlighet att filtrera på metadata så att exempelvis övriga öar kan filtreras bort innan retrieval. Detta ligger dock utanför denna uppgiftens scope tyvärr.

# %%
query = " Hvar, Zlatan Otok, vinprovning"
query_embedding = service.embed(query)
results = store.search(query_embedding, k=5)

for i, row in enumerate(results, start=1):
    print("=" * 80)
    print(f"Resultat {i}")
    print(f"Similarity: {row['similarity']:.3f}")
    print(f"Kurs: {row.get('course_name', '-')}")
    print(f"Kapitel: {row.get('chapter_title', '-')}")
    print(f"Text:\n{row['text'][:1500]}")
    print()
# Out:
# ...
# Resultat 1
# Similarity: 0.848
# Kurs: Destination: Kroatien
# Kapitel: Hvar
# Text:
# ...
